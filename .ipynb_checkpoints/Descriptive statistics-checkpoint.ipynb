# %%
# Import libraries
import pandas as pd
import numpy as np
import datetime as dt
import os
import math

# %% [markdown]
# Naming convention for dataframes:
#
# * sd - Secchi disk depth
#
# * t - turbidity
#
# * tss - total suspended solids
#
# * c - chlorophyll
#
# * tcc - total cell count
#
#     * tcc_c - total cell count (composite)
#
#     * tcc_s - total cell count (surface)
#
# * tb - total biovolume
#
#     * tb_c - total biovolume (composite)
#
#     * tb_s - total biovolume (surface)
#
# * ccc - cyano cell count
#
#     * ccc_c - cyano cell count (composite)
#
#     * ccc_s - cyano cell count (surface)
#
# * cb - cyano biovolume
#
#     * cb_c - cyano biovolume (composite)
#
#     * cb_s - cyano biovolume (surface)

# %%
# Locate folder with csv for each variable
data_folder = "../../data/processed/regression/"
files = os.listdir(data_folder)

# %%
# Check CSV files in the folder
files
# Out:
# ['chlorophyll_final.csv',
#  'cyano_biovolume_composite_final.csv',
#  'cyano_biovolume_final.csv',
#  'cyano_biovolume_surface_final.csv',
#  'cyano_cell_count_composite_final.csv',
#  'cyano_cell_count_final.csv',
#  'cyano_cell_count_surface_final.csv',
#  'secchi_depth_final.csv',
#  'total_biovolume_composite_final.csv',
#  'total_biovolume_final.csv',
#  'total_biovolume_surface_final.csv',
#  'total_cell_count_composite_final.csv',
#  'total_cell_count_final.csv',
#  'total_cell_count_surface_final.csv',
#  'total_suspended_solids_final.csv',
#  'turbidity_final.csv',
#  'tweets_daily_final.csv']

# %%
# Create a dictionary to hold all the dataframes
df = {}

# Name of dataframe indices - align with the order of files
names = ["c", "cb_c", "cb", "cb_s", "ccc_c", "ccc", "ccc_s", "sd", "tb_c", 
         "tb", "tb_s", "tcc_c", "tcc", "tcc_s", "tss", "t", "tweets"]

# %%
# Import data
for name, file in zip(names, files):
        df[name] = pd.read_csv(f'{data_folder}{file}')

# %%
# Convert date column to datetime object
for file in df.keys():
    # seaprate if statement for tweets dataframe because its date column has a different name
    if file == "tweets":
        df[file]['time'] = pd.to_datetime(df[file]['time'])
    else:
        df[file]["OBJECTID_1"] = pd.to_datetime(df[file]["OBJECTID_1"])
        df[file].columns = df[file].columns.str.replace(".", "")
        df[file] = df[file]['X75']

# %%
df
# Out:
# {'c': 0      19.578767
#  1      22.789905
#  2       4.606094
#  3      11.701630
#  4      82.581816
#  5      73.952105
#  6      12.704681
#  7      45.556070
#  8       8.866609
#  9      10.038378
#  10     26.316612
#  11    305.672119
#  12     45.265713
#  13    100.194262
#  14     81.669596
#  15     40.521667
#  16     53.001339
#  17     23.921853
#  18     50.543127
#  19     16.098199
#  20     11.004787
#  21     33.521324
#  22      8.969109
#  23     20.375231
#  24      3.086706
#  25     23.119865
#  26     61.140789
#  27      4.850000
#  28     14.083227
#  29     10.909076
#  30     24.943311
#  31    123.766667
#  32     13.560000
#  33     85.200000
#  34    218.000000
#  35     34.956667
#  36     22.280000
#  Name: X75, dtype: float64, 'cb_c': 0     1.802942e+05
#  1     6.181867e+03
#  2     5.925051e+05
#  3     7.752958e+07
#  4     2.397550e+06
#  5     2.813747e+07
#  6     7.661239e+06
#  7     1.129411e+07
#  8     1.555847e+08
#  9     5.050182e+08
#  10    1.958967e+07
#  11    3.141613e+06
#  36    8.087401e+06
#  37    2.542247e+06
#  38    2.221094e+06
#  39    7.652796e+06
#  40    8.796263e+04
#  41    2.699606e+06
#  42    1.527408e+05
#  43    5.300689e+05
#  44    3.991847e+06
#  45    8.168761e+04
#  46    7.777931e+06
#  47    4.986629e+05
#  48    1.262490e+06
#  49    2.620944e+04
#  50    1.763676e+05
#  51    1.152291e+05
#  52    3.909309e+04
#  Name: X75, dtype: float64, 'tss': 0       8.141370
#  1     117.412632
#  2     119.222500
#  3      51.387360
#  4      78.273655
#           ...
#  58     14.400000
#  59     90.000000
#  60     58.000000
#  61      7.000000
#  62    124.200000
#  Name: X75, Length: 63, dtype: float64, 't': 0      90.624678
#  1      48.808829
#  2      38.875797
#  3      32.734902
#  4      89.202103
#  5      79.332632
#  6      43.233678
#  7      34.736864
#  8      53.300739
#  9      49.558949
#  10     39.372334
#  11     86.387405
#  12    169.558590
#  13     69.741047
#  14     60.893748
#  15     65.111012
#  16    102.892443
#  17     71.585083
#  18    129.367065
#  19     90.093727
#  20     33.397321
#  21     31.402065
#  22     57.362465
#  23     64.402941
#  24     39.366701
#  25     20.697708
#  26     23.500568
#  27     27.648317
#  28     53.588611
#  29     88.363346
#  30     62.093691
#  31     67.690212
#  32     79.000000
#  33      8.910000
#  34     25.600000
#  35    105.000000
#  36     46.200000
#  37      6.400000
#  Name: X75, dtype: float64, 'tweets':            time  water quality?  neg  pos
#  0    2016-01-01             0.0  0.0  0.0
#  1    2016-01-02             0.0  0.0  0.0
#  2    2016-01-03             0.0  0.0  0.0
#  3    2016-01-04             0.0  0.0  0.0
#  4    2016-01-05             0.0  0.0  0.0
#  ...         ...             ...  ...  ...
#  1818 2020-12-23             0.0  0.0  0.0
#  1819 2020-12-24             0.0  0.0  0.0
#  1820 2020-12-25             0.0  0.0  0.0
#  1821 2020-12-26             0.0  0.0  0.0
#  1822 2020-12-27             0.0  0.0  0.0
#
#  [1823 rows x 4 columns]}

# %%
# number of observations, min, 2th percentile, median, 75th percentile, max, mean, range, variance

# %%
# Name of dataframe indices - align with the order of files
y_names = ['sd', 't', 'c', 'tss', 'tcc_c', 'tcc_s', 'tb_c', 'tb_s', 
         'ccc_c', 'ccc_s', 'cb_c', 'cb_s'] 

# Create a dataframe for descriptive statistics
desc_stats = pd.DataFrame(
                      index = ['Secchi disk depth', 'Turbidity', 'Chlorophyll a', 'Total suspended solids',
                      'Phytoplankton cell count (Composite)', 'Phytoplankton cell count (Surface)',
                      'Phytoplankton biovolume (Composite)', 'Phytoplankton biovolume (Surface)',
                      'Cyanobacteria cell count (Composite)', 'Cyanobacteria cell count (Surface)', 
                      'Cyanobacteria biovolume (Composite)', 'Cyanobacteria biovolume (Surface)'],
                      columns = ['Minimum', '25th Percentile', 'Median', '75th Percentile', 
                                'Maximum', 'Mean', 'Range', 'Variance']
                     )

# %%
# Iterate through each row
for i in range(0, len(desc_stats)):
    
    desc_stats.iloc[i,0] = min(df[y_names[i]])
    desc_stats.iloc[i,1] = np.percentile(df[y_names[i]], 25)
    desc_stats.iloc[i,2] = np.percentile(df[y_names[i]], 50) #np.median(df[y_names[i]])
    desc_stats.iloc[i,3] = np.percentile(df[y_names[i]], 75)
    desc_stats.iloc[i,4] = max(df[y_names[i]])
    desc_stats.iloc[i,5] = np.mean(df[y_names[i]])
    desc_stats.iloc[i,6] = max(df[y_names[i]]) - min(df[y_names[i]])
    desc_stats.iloc[i,7] = np.var(df[y_names[i]])

# %%
desc_stats
# Out:
#                                           Minimum 25th Percentile  \
# Secchi disk depth                             0.1             0.2
# Turbidity                                     6.4         35.7716
# Chlorophyll a                             3.08671         12.7047
# Total suspended solids                          7         35.1624
# Phytoplankton cell count (Composite)            0         28883.1
# Phytoplankton cell count (Surface)        888.795          110795
# Phytoplankton biovolume (Composite)        899563     9.20091e+06
# Phytoplankton biovolume (Surface)     1.20044e+07     1.12529e+08
# Cyanobacteria cell count (Composite)      159.157         11035.8
# Cyanobacteria cell count (Surface)        41.8926         57899.9
# Cyanobacteria biovolume (Composite)       6181.87     1.66081e+06
# Cyanobacteria biovolume (Surface)         4817.23     4.29048e+07
#
#                                            Median 75th Percentile  \
# Secchi disk depth                        0.247276        0.305438
# Turbidity                                 55.4755         79.2495
# Chlorophyll a                             23.9219         53.0013
# Total suspended solids                     61.275         96.8559
# Phytoplankton cell count (Composite)      61214.6          289725
# Phytoplankton cell count (Surface)    1.08909e+06     3.72999e+06
# Phytoplankton biovolume (Composite)   1.37581e+07     3.03274e+07
# Phytoplankton biovolume (Surface)     1.04206e+09     2.51363e+09
# Cyanobacteria cell count (Composite)      46144.6          240951
# Cyanobacteria cell count (Surface)         726344      3.8528e+06
# Cyanobacteria biovolume (Composite)   5.09452e+06     2.11689e+07
# Cyanobacteria biovolume (Surface)     7.97453e+08     2.92035e+09
#
#                                           Maximum         Mean        Range  \
# Secchi disk depth                        0.854711     0.277585     0.754711
# Turbidity                                 169.559      60.1588      163.159
# Chlorophyll a                             305.672      47.2797      302.585
# Total suspended solids                    334.364      74.0852      327.364
# Phytoplankton cell count (Composite)  4.52023e+07  1.51786e+06  4.52023e+07
# Phytoplankton cell count (Surface)    4.91182e+07  4.66559e+06  4.91174e+07
# Phytoplankton biovolume (Composite)   5.21405e+08  4.75559e+07  5.20505e+08
# Phytoplankton biovolume (Surface)     9.16887e+09  1.99882e+09  9.15686e+09
# Cyanobacteria cell count (Composite)  4.52023e+07  1.25399e+06  4.52022e+07
# Cyanobacteria cell count (Surface)    1.03588e+08  6.03532e+06  1.03588e+08
# Cyanobacteria biovolume (Composite)   5.05018e+08  3.40073e+07  5.05012e+08
# Cyanobacteria biovolume (Surface)     6.56507e+09  1.80869e+09  6.56506e+09
#
#                                          Variance
# Secchi disk depth                       0.0210185
# Turbidity                                 1093.23
# Chlorophyll a                             3588.36
# Total suspended solids                    3317.69
# Phytoplankton cell count (Composite)  4.29235e+13
# Phytoplankton cell count (Surface)    8.70218e+13
# Phytoplankton biovolume (Composite)   8.45108e+15
# Phytoplankton biovolume (Surface)     6.17888e+18
# Cyanobacteria cell count (Composite)  3.49969e+13
# Cyanobacteria cell count (Surface)    2.34554e+14
# Cyanobacteria biovolume (Composite)   6.94988e+15
# Cyanobacteria biovolume (Surface)     4.86341e+18

# %%
# Export
desc_stats.to_excel("../../output/descriptive stats/wq_descriptive_stats.xlsx")
