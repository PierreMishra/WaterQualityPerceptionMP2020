# %% [markdown]
# # Collecting Tweets using Tweepy

# %%
# Load packages
import tweepy as tw #make sure to install v3.10
import pandas as pd
import numpy as np
# install preprocessor using pip install via Command Prompt/Anaconda prompt: pip install tweet-preprocessor
from preprocessor import api as p
#from preprocessor.api import clean, tokenize, parse #to clean tweets

# %%
# Credentials
access_token = "1311658729201377281-alEuRquK89jGbga7ckTsFhIlkRVPOY"
access_token_secret = "rpQowQaio69m3XMByxXEzUdo73WPnpaPuYTQpAFH9cjoa"
api_key = "E0RK2oHynrMIJ9YVrvuhIIjc6"
api_key_secret = "kHnfmtYn7J66MkR7bUE3BTnWsW64ZUDUIxtw9bThP5kmDjq0Vl"

# %%
# Authentication app
auth = tw.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth)

# %%
# Find by phrase or keywords within a specified time
search_words = '"utah lake" has:links'
#search_words = '"utah lake" -has:links' 
# we can not use -filter:links etc for premium API search
# use this link instead https://developer.twitter.com/en/docs/twitter-api/premium/rules-and-filtering/using-premium-operators
# it is equivalent to utah lake until:2020-12-20 since:2020-11-28 -filter:links
# we can't filter out retweets in the premium search

# advanced search in Twitter search box 
# utah lake (#utahlake) until:2020-12-03 since:2020-11-28 -filter:links -filter:retweets
# If I include hashtag in search, it wouldn't show the ones without hashtag
# May be we can have a separate search by #utahlake and then combine both the dataframes

# From date, to date, for premium API search the date should be in format yyyyMMddHHmm
year = int(input("Year: "))
date_since = f'{year}01010000' #from January 1st, 12:00AM UTC
#date_until = f'{year}12312359' #to December 31st, 11:59PM UTC
date_until = f'{year}12300300' #for 2020 3AM UTC

#date_since = f'{year}12250000' #test
#date_until = f'{year}12280000' #test

# Create a cursor object that iterates over the requested information
# had to create a dev environment named "SentimentAnalysis" in Twitter's Developer Portal
tweets = tw.Cursor(api.search_full_archive, environment_name = "SentimentAnalysis",
                   query=search_words,
                   fromDate=date_since, toDate=date_until).items()

# Parse the cursor object into rows of lists using list comprehension
#rows = [[tweet.user.location, tweet.text, tweet.created_at, tweet.coordinates] for tweet in tweets]

# Make a list to store each item return in a payload
rows = []

# Iterate through each object and get location, tweet, date, coordinates and place for each record
for tweet in tweets:
    
    # check if there is an 'extended_tweet' property
    if ('extended_tweet' in dir(tweet)) == True: 
        # if so, instead of 'text', get 'full_text'
        row = [tweet.user.location, tweet.extended_tweet['full_text'], tweet.created_at, tweet.coordinates, tweet.retweeted, tweet.place]
    else:
        row = [tweet.user.location, tweet.text, tweet.created_at, tweet.coordinates, tweet.retweeted, tweet.place]

    # Append each item to the list
    rows.append(row)

# Tweets starting with an RT mean that they are retweets 

# more on geo-referenced tweets: 
# https://developer.twitter.com/en/docs/twitter-api/v1/data-dictionary/object-model/geo
# if required, look into user.derived.locations.geo
# it assigns lat/long based on user's profile and the geographic precision they set
# for example, if a user set their precision at the country-level, it will show center of US at lat/long
# so it is not too accurate and might be irrelevant to us
# https://developer.twitter.com/en/docs/twitter-api/enterprise/enrichments/overview/profile-geo
# Out:
# Year: 2020

# %%
# Create dataframe from the rows of lists
df_tweet = pd.DataFrame(data=rows, columns=['location', 'tweet', 'time', 'coordinates', 'retweeted', 'place'])

# %%
# Add ID column (because we removed user information)
unique_id = np.arange(len(df_tweet))
df_tweet['id'] = unique_id + 1
df_tweet = df_tweet[['id', 'location', 'tweet', 'time', 'coordinates', 'retweeted', 'place']]

# %%
df_tweet.head(50)
# Out:
#     id                     location  \
# 0    1                  Provo, Utah
# 1    2                    Provo, UT
# 2    3                         utah
# 3    4                     Orem, UT
# 4    5           Salt Lake City, UT
# 5    6              West Jordan, UT
# 6    7       Montana, United States
# 7    8               Washington, DC
# 8    9                    Provo, UT
# 9   10                Norway - Utah
# 10  11                    Utah, USA
# 11  12                      London
# 12  13                         utah
# 13  14                    Provo, UT
# 14  15              West Jordan, UT
# 15  16                 Newburgh, IN
# 16  17    Western Hemisphere, Earth
# 17  18                         Utah
# 18  19                   Malibu, CA
# 19  20                         None
# 20  21                          USA
# 21  22                          USA
# 22  23                  Provo, Utah
# 23  24                         None
# 24  25                 Planet Earth
# 25  26          Southern California
# 26  27          Birmingham, Alabama
# 27  28                Anywhere Cold
# 28  29                  boston mass
# 29  30          Palmetto, FL. 34221
# 30  31               Plainfield, IL
# 31  32                  chicagoLand
# 32  33                         None
# 33  34                         None
# 34  35                         None
# 35  36      Texan Living In Florida
# 36  37                         None
# 37  38                       Global
# 38  39            The Twilight Zone
# 39  40             Papua New Guinea
# 40  41                         None
# 41  42  Zürich 🇨🇭 • San Francisco 🌉
# 42  43           Salt Lake City, UT
# 43  44                         None
# 44  45               United Kingdom
# 45  46         A long way from home
# 46  47                         None
# 47  48                         None
# 48  49                         Utah
# 49  50           Salt Lake City, UT
#
#                                                 tweet                time  \
# 0   Just the right combination of cold temperature... 2020-12-30 02:00:04
# 1   RT @workingitoutnow: Went to Utah Lake around ... 2020-12-30 01:44:28
# 2   Sun star over Utah lake . @UtahLake #utahlake ... 2020-12-30 01:37:06
# 3   Went to Utah Lake around sunset to see the bro... 2020-12-30 01:25:07
# 4   Remember the #Halloween party at the Knolls ne... 2020-12-29 23:47:40
# 5   Mother Nature showing off some of her ice art ... 2020-12-29 12:07:16
# 6   @SandyForLiberty Utah lake from the west side ... 2020-12-29 10:04:27
# 7   It's all very simple, see. The Provo Red Ensig... 2020-12-29 05:16:05
# 8   RT @PrestonPhotog: Utah Lake this morning look... 2020-12-29 04:02:15
# 9   RT @KUTV2News: STUNNING! 😲 Just look at that s... 2020-12-28 21:39:39
# 10  Utah Lake this morning looking gloomy with the... 2020-12-28 18:31:48
# 11  RT @KUTV2News: STUNNING! 😲 Just look at that s... 2020-12-28 18:25:00
# 12  @CanonUSAimaging #CanonFavPic @CanonUSAimaging... 2020-12-28 15:41:27
# 15        None      False                                               None
# 16        None      False                                               None
# 17        None      False                                               None
# 18        None      False                                               None
# 19        None      False                                               None
# 20        None      False                                               None
# 21        None      False                                               None
# 22        None      False                                               None
# 23        None      False                                               None
# 24        None      False                                               None
# 25        None      False                                               None
# 26        None      False                                               None
# 27        None      False                                               None
# 28        None      False                                               None
# 29        None      False                                               None
# 30        None      False                                               None
# 31        None      False                                               None
# 32        None      False                                               None
# 33        None      False                                               None
# 34        None      False                                               None
# 35        None      False                                               None
# 36        None      False                                               None
# 37        None      False                                               None
# 38        None      False                                               None
# 39        None      False                                               None
# 40        None      False                                               None
# 41        None      False                                               None
# 42        None      False                                               None
# 43        None      False                                               None
# 44        None      False                                               None
# 45        None      False                                               None
# 46        None      False                                               None
# 47        None      False                                               None
# 48        None      False                                               None
# 49        None      False                                               None

# %%
df_tweet.tail()
# Out:
#         id          location  \
# 3750  3751         Provo, UT
# 3751  3752            México
# 3752  3753     United States
# 3753  3754              None
# 3754  3755  Toronto, Ontario
#
#                                                   tweet                time  \
# 3750  Utah County has several cities and towns dotti... 2020-01-02 22:00:06
# 3751  RT @flyctrobin: Ghost (me), Draco (Mike) and B... 2020-01-02 20:06:11
# 3752  Ghost (me), Draco (Mike) and Best Tugs (Mark) ... 2020-01-02 20:02:25
# 3753  Baby, its cold outside 🥶 @AutosIncUtah @ Utah ... 2020-01-02 02:22:00
# 3754  Ice stacking on Utah lake. https://t.co/EEUF2x... 2020-01-01 20:29:18
#
#      coordinates  retweeted place
# 3750        None      False  None
# 3751        None      False  None
# 3752        None      False  None
# 3753        None      False  None
# 3754        None      False  None

# %%
df_tweet.tweet[1]
# Out:
# 'RT @workingitoutnow: Went to Utah Lake around sunset to see the broken ice sheets. I was not disappointed. #utahlake @utahlake @vineyardcit…'

# %%
df_tweet.place[1]

# %% [markdown]
# # Cleaning tweets in the dataframe

# %% [markdown]
# #### Lets clean tweets after labeling

# %%
# # Clean each tweet in our dataframe using the preprocessor module
# tweet_clean = []
# for tweet in df_tweet['tweet']:
#     cleaned = p.clean(tweet)
#     tweet_clean.append(cleaned)

# %%
# # Store as a new dataframe
# df_tweet_clean = df_tweet.copy()
# df_tweet_clean['tweet'] = tweet_clean

# %%
#df_tweet_clean.head()

# %% [markdown]
# # Save the dataframe as a CSV

# %%
# Checking current working directory
import os
os.getcwd()
# Out:
# 'C:\\Users\\rapiduser\\Documents\\WaterQualityPerception\\Pierre\\WaterQualityPerceptionMP2020'

# %%
# Store as CSV to a relative path
#df_tweet.to_csv(f"..\\..\\Data\\utahlake_{year}.csv")
df_tweet.to_csv(f"..\\..\\Data\\utahlake_{year}_links.csv")
#df_tweet_clean.to_csv(f"..\\..\\Data\\utahlake_{year}.csv")
#df_tweet_clean.to_csv("..\\..\\Data\\scraped_tweets_test.csv")
