# %%
# Import libraries
import pandas as pd
import numpy as np
import datetime as dt

# %% [markdown]
# # I. Routine Water Quality Data

# %%
# Import Kateri's processed water quality data
df = pd.read_csv("../../data/raw/ul_data_wqp_processed_2020-03-05.csv")

# %%
# Selecting relevant columns
df = df.loc[:,["MonitoringLocationIdentifier",'MonitoringLocationName', "datetime",
               "CharacteristicName", "ResultMeasureValue",
               "LatitudeMeasure", "LongitudeMeasure"]].copy()

# %%
# Transform table
wq = df.pivot_table("ResultMeasureValue", ['MonitoringLocationIdentifier','MonitoringLocationName',
                                           'datetime',
                                           "LatitudeMeasure", "LongitudeMeasure"],'CharacteristicName') 
wq.columns.name = ''
# wq = wq.reset_index()
# wq.datetime = pd.to_datetime(wq['datetime'])

# %%
# Take average to get daily values and get rid of hourly variation for some monitoring locations
# wq = wq.groupby(['MonitoringLocationIdentifier',
#                  pd.Grouper(key='datetime', freq='D')])[wq.columns[5:]].mean()

# %%
# Make datetime column datetime type
wq = wq.reset_index()
wq.datetime = pd.to_datetime(wq['datetime'])

# %%
# Select rows from 2016
wq_16 = wq.loc[wq['datetime'] > '2015-12-31']

# %%
wq_16.head()
# Out:
#    MonitoringLocationIdentifier  \
# 2          USGS-401327111462601
# 3          USGS-401432111454301
# 4          USGS-401613111463301
# 5          USGS-401658111491601
# 13          UTAHDWQ_WQX-4917305
#
#                               MonitoringLocationName            datetime  \
# 2                         UTAH LAKE HAB STUDY SITE 3 2016-08-10 13:05:00
# 3                         UTAH LAKE HAB STUDY SITE 4 2016-08-10 15:15:00
# 4                         UTAH LAKE HAB STUDY SITE 1 2016-08-10 10:15:00
# 5                         UTAH LAKE HAB STUDY SITE 2 2016-08-10 11:30:00
# 13  Utah Lake at American Fork Marina near boat ramp 2016-09-26 12:15:00
#
#     LatitudeMeasure  LongitudeMeasure  Alkalinity, total  Aluminum  \
# 2         40.224119       -111.773939              163.0       NaN
# 3         40.242311       -111.761811              165.0       NaN
# 4         40.270319       -111.775881              164.0       NaN
# 5         40.282700       -111.821200              166.0       NaN
# 13        40.342380       -111.800839                NaN       NaN
#
#     Ammonia-nitrogen  Arsenic  Barium  ...  Total Kjeldahl nitrogen  \
# 2                NaN      NaN     NaN  ...                      NaN
# 3                NaN      NaN     NaN  ...                      NaN
# 4                NaN      NaN     NaN  ...                      NaN
# 5                NaN      NaN     NaN  ...                      NaN
# 13               NaN      NaN     NaN  ...                      NaN
#
#     Total dissolved solids  Total fixed solids  Total suspended solids  \
# 2              1037.386667                 NaN                     NaN
# 3              1034.040000                 NaN                     NaN
# 4               980.683333                 NaN                     NaN
# 5              1050.723333                 NaN                     NaN
# 13                     NaN                 NaN                     NaN
#
#     Total volatile solids  Turbidity  Volatile suspended solids  \
# 2                     NaN      110.0                        NaN
# 3                     NaN       74.0                        NaN
# 4                     NaN      100.0                        NaN
# 5                     NaN       59.0                        NaN
# 13                    NaN        NaN                        NaN
#
#     Weather condition (WMO code 4501) (choice list)  Zinc  pH
# 2                                               NaN   NaN NaN
# 3                                               NaN   NaN NaN
# 4                                               NaN   NaN NaN
# 5                                               NaN   NaN NaN
# 13                                              NaN   NaN NaN
#
# [5 rows x 80 columns]

# %%
# Select variables of interest
pred = wq_16.loc[:,["MonitoringLocationIdentifier", "MonitoringLocationName",
                    "datetime",
                    "LatitudeMeasure", "LongitudeMeasure",
                    "Depth, Secchi disk depth", "Turbidity",
                    "Total suspended solids",
                    "Chlorophyll a, uncorrected for pheophytin", 
                     "Chlorophyll a, corrected for pheophytin",
                    "Chlorophyll a, free of pheophytin"]].copy()

# %% [markdown]
# ## Secchi disk depth

# %%
# Extract chlorophyll values
depth = pred.loc[:,["MonitoringLocationIdentifier", "MonitoringLocationName","datetime",
                    "LatitudeMeasure", "LongitudeMeasure","Depth, Secchi disk depth"]]

# %%
depth.head(50)
# Out:
#     MonitoringLocationIdentifier  \
# 2           USGS-401327111462601
# 3           USGS-401432111454301
# 4           USGS-401613111463301
# 5           USGS-401658111491601
# 13           UTAHDWQ_WQX-4917305
# 14           UTAHDWQ_WQX-4917305
# 15           UTAHDWQ_WQX-4917305
# 16           UTAHDWQ_WQX-4917305
# 17           UTAHDWQ_WQX-4917305
# 18           UTAHDWQ_WQX-4917305
# 19           UTAHDWQ_WQX-4917305
# 20           UTAHDWQ_WQX-4917305
# 21           UTAHDWQ_WQX-4917305
# 22           UTAHDWQ_WQX-4917305
# 23           UTAHDWQ_WQX-4917305
# 24           UTAHDWQ_WQX-4917305
# 25           UTAHDWQ_WQX-4917305
# 26           UTAHDWQ_WQX-4917305
# 27           UTAHDWQ_WQX-4917305
# 28           UTAHDWQ_WQX-4917305
# 29           UTAHDWQ_WQX-4917305
# 30           UTAHDWQ_WQX-4917305
# 31           UTAHDWQ_WQX-4917305
# 32           UTAHDWQ_WQX-4917305
# 105          UTAHDWQ_WQX-4917310
# 106          UTAHDWQ_WQX-4917310
# 107          UTAHDWQ_WQX-4917310
# 108          UTAHDWQ_WQX-4917310
# 109          UTAHDWQ_WQX-4917310
# 110          UTAHDWQ_WQX-4917310
# 111          UTAHDWQ_WQX-4917310
# 112          UTAHDWQ_WQX-4917310
# 113          UTAHDWQ_WQX-4917310
# 114          UTAHDWQ_WQX-4917310
# 115          UTAHDWQ_WQX-4917310
# 116          UTAHDWQ_WQX-4917310
# 117          UTAHDWQ_WQX-4917310
# 118          UTAHDWQ_WQX-4917310
# 119          UTAHDWQ_WQX-4917310
# 120          UTAHDWQ_WQX-4917310
# 121          UTAHDWQ_WQX-4917310
# 122          UTAHDWQ_WQX-4917310
# 123          UTAHDWQ_WQX-4917310
# 124          UTAHDWQ_WQX-4917310
# 125          UTAHDWQ_WQX-4917310
# 126          UTAHDWQ_WQX-4917310
# 127          UTAHDWQ_WQX-4917310
# 128          UTAHDWQ_WQX-4917323
# 129          UTAHDWQ_WQX-4917323
# 145          UTAHDWQ_WQX-4917333
#
#                                MonitoringLocationName            datetime  \
# 2                          UTAH LAKE HAB STUDY SITE 3 2016-08-10 13:05:00
# 3                          UTAH LAKE HAB STUDY SITE 4 2016-08-10 15:15:00
# 19         40.342380       -111.800839                       NaN
# 20         40.342380       -111.800839                       NaN
# 21         40.342380       -111.800839                       NaN
# 22         40.342380       -111.800839                       NaN
# 23         40.342380       -111.800839                       NaN
# 24         40.342380       -111.800839                       NaN
# 25         40.342380       -111.800839                       NaN
# 26         40.342380       -111.800839                       NaN
# 27         40.342380       -111.800839                       NaN
# 28         40.342380       -111.800839                       NaN
# 29         40.342380       -111.800839                       NaN
# 30         40.342380       -111.800839                       NaN
# 31         40.342380       -111.800839                       NaN
# 32         40.342380       -111.800839                       NaN
# 105        40.320873       -111.777538                      0.20
# 106        40.320873       -111.777538                      0.20
# 107        40.320873       -111.777538                      0.20
# 108        40.320873       -111.777538                      0.25
# 109        40.320873       -111.777538                      0.40
# 110        40.320873       -111.777538                      0.20
# 111        40.320873       -111.777538                      0.20
# 112        40.320873       -111.777538                      0.30
# 113        40.320873       -111.777538                      0.20
# 114        40.320873       -111.777538                      0.20
# 115        40.320873       -111.777538                      0.25
# 116        40.320873       -111.777538                      0.20
# 117        40.320873       -111.777538                      0.20
# 118        40.320873       -111.777538                      0.25
# 119        40.320873       -111.777538                       NaN
# 120        40.320873       -111.777538                      0.30
# 121        40.320873       -111.777538                      0.20
# 122        40.320873       -111.777538                      0.20
# 123        40.320873       -111.777538                      0.42
# 124        40.320873       -111.777538                      0.65
# 125        40.320873       -111.777538                      0.30
# 126        40.320873       -111.777538                      0.20
# 127        40.320873       -111.777538                      0.20
# 128        40.325868       -111.765995                       NaN
# 129        40.325868       -111.765995                       NaN
# 145        40.329470       -111.765290                       NaN

# %%
# rename columns
depth = depth.rename(columns={'MonitoringLocationIdentifier':'mlid',
                              'MonitoringLocationName':'location',
                              'LatitudeMeasure':'lat',
                              'LongitudeMeasure':'long',
                              'Depth, Secchi disk depth':'secchi_depth_meters'
                             }, inplace=False)

# %%
# Check column types
depth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 611 entries, 2 to 1242
# Data columns (total 6 columns):
# mlid                   611 non-null object
# location               611 non-null object
# datetime               611 non-null datetime64[ns]
# lat                    611 non-null float64
# long                   611 non-null float64
# secchi_depth_meters    230 non-null float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 33.4+ KB

# %%
# Change date format
depth['datetime'] = depth['datetime'].dt.strftime('%Y%m%d')

# %%
# Export 
depth.to_csv("../../data/processed/secchi_depth.csv", index=False)

# %%
#take mean for same location on same day????????

# %% [markdown]
# ## Turbidity

# %%
# Extract chlorophyll values
turbidity = pred.loc[:,["MonitoringLocationIdentifier", "MonitoringLocationName","datetime",
                        "LatitudeMeasure", "LongitudeMeasure","Turbidity"]]

# %%
turbidity.head(50)
# Out:
#     MonitoringLocationIdentifier  \
# 2           USGS-401327111462601
# 3           USGS-401432111454301
# 4           USGS-401613111463301
# 5           USGS-401658111491601
# 13           UTAHDWQ_WQX-4917305
# 14           UTAHDWQ_WQX-4917305
# 15           UTAHDWQ_WQX-4917305
# 16           UTAHDWQ_WQX-4917305
# 17           UTAHDWQ_WQX-4917305
# 18           UTAHDWQ_WQX-4917305
# 19           UTAHDWQ_WQX-4917305
# 20           UTAHDWQ_WQX-4917305
# 28   Utah Lake at American Fork Marina near boat ramp 2019-05-07 12:34:00
# 29   Utah Lake at American Fork Marina near boat ramp 2019-06-05 12:15:00
# 30   Utah Lake at American Fork Marina near boat ramp 2019-07-09 11:45:00
# 31   Utah Lake at American Fork Marina near boat ramp 2019-08-07 12:10:00
# 32   Utah Lake at American Fork Marina near boat ramp 2019-09-12 13:20:00
# 105      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2016-04-20 10:10:00
# 106      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2016-05-25 08:11:04
# 107      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2016-06-30 08:13:56
# 108      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2017-05-11 10:40:00
# 109      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2017-06-15 16:46:00
# 110      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2017-07-11 17:23:17
# 111      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2017-08-08 12:44:20
# 112      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2017-09-11 16:46:08
# 113      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2017-10-16 15:00:00
# 114      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2017-11-08 15:13:00
# 115      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2018-05-16 13:58:22
# 116      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2018-06-12 13:54:20
# 117      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2018-07-11 12:53:17
# 118      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2018-08-09 13:12:00
# 119      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2018-09-19 14:29:21
# 120      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2018-10-10 11:15:00
# 121      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2018-11-14 12:09:00
# 122      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2019-04-18 09:55:00
# 123      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2019-05-13 11:00:00
# 124      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2019-06-17 11:00:00
# 125      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2019-07-08 10:52:14
# 126      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2019-08-12 10:20:00
# 127      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2019-09-23 14:15:00
# 128       Utah Lake south of Lindon Marina south dike 2016-11-02 09:45:00
# 129       Utah Lake south of Lindon Marina south dike 2017-05-11 14:06:00
# 145                          Utah Lake @ Lindon Beach 2016-09-26 12:50:00
#
#      LatitudeMeasure  LongitudeMeasure  Turbidity
# 2          40.224119       -111.773939     110.00
# 3          40.242311       -111.761811      74.00
# 4          40.270319       -111.775881     100.00
# 5          40.282700       -111.821200      59.00
# 13         40.342380       -111.800839        NaN
# 14         40.342380       -111.800839        NaN
# 15         40.342380       -111.800839        NaN
# 16         40.342380       -111.800839        NaN
# 17         40.342380       -111.800839        NaN
# 18         40.342380       -111.800839        NaN
# 19         40.342380       -111.800839        NaN
# 20         40.342380       -111.800839        NaN
# 21         40.342380       -111.800839        NaN
# 22         40.342380       -111.800839        NaN
# 23         40.342380       -111.800839        NaN
# 24         40.342380       -111.800839        NaN
# 25         40.342380       -111.800839        NaN
# 26         40.342380       -111.800839        NaN
# 27         40.342380       -111.800839        NaN
# 28         40.342380       -111.800839        NaN
# 29         40.342380       -111.800839        NaN
# 30         40.342380       -111.800839        NaN
# 31         40.342380       -111.800839        NaN
# 32         40.342380       -111.800839        NaN
# 105        40.320873       -111.777538        NaN
# 106        40.320873       -111.777538        NaN
# 107        40.320873       -111.777538        NaN
# 108        40.320873       -111.777538      54.10
# 109        40.320873       -111.777538      31.00
# 110        40.320873       -111.777538      63.50
# 111        40.320873       -111.777538      48.50
# 112        40.320873       -111.777538      35.10
# 113        40.320873       -111.777538      76.00
# 114        40.320873       -111.777538      38.60
# 115        40.320873       -111.777538      39.60
# 116        40.320873       -111.777538      27.60
# 117        40.320873       -111.777538      55.70
# 118        40.320873       -111.777538      41.30
# 119        40.320873       -111.777538      69.20
# 120        40.320873       -111.777538      94.40
# 121        40.320873       -111.777538      27.60
# 122        40.320873       -111.777538      80.45
# 123        40.320873       -111.777538      49.85
# 124        40.320873       -111.777538      18.95
# 125        40.320873       -111.777538      47.40
# 126        40.320873       -111.777538      87.55
# 127        40.320873       -111.777538      65.10
# 128        40.325868       -111.765995        NaN
# 129        40.325868       -111.765995        NaN
# 145        40.329470       -111.765290        NaN

# %%
# rename columns
turbidity = turbidity.rename(columns={'MonitoringLocationIdentifier':'mlid',
                              'MonitoringLocationName':'location',
                              'LatitudeMeasure':'lat',
                              'LongitudeMeasure':'long',
                              'Turbidity':'turbidity'
                             }, inplace=False)

# %%
# Check column types
turbidity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 611 entries, 2 to 1242
# Data columns (total 6 columns):
# mlid         611 non-null object
# location     611 non-null object
# datetime     611 non-null datetime64[ns]
# lat          611 non-null float64
# long         611 non-null float64
# turbidity    225 non-null float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 33.4+ KB

# %%
# Change date format
turbidity['datetime'] = turbidity['datetime'].dt.strftime('%Y%m%d')

# %%
# Export 
turbidity.to_csv("../../data/processed/turbidity.csv", index=False)

# %%
#take mean for same location on same day????????

# %% [markdown]
# ## Total suspended solids

# %%
# Extract chlorophyll values
tss = pred.loc[:,["MonitoringLocationIdentifier", "MonitoringLocationName","datetime",
                        "LatitudeMeasure", "LongitudeMeasure","Total suspended solids"]]

# %%
tss.head(50)
# Out:
#     MonitoringLocationIdentifier  \
# 2           USGS-401327111462601
# 3           USGS-401432111454301
# 4           USGS-401613111463301
# 5           USGS-401658111491601
# 13           UTAHDWQ_WQX-4917305
# 14           UTAHDWQ_WQX-4917305
# 15           UTAHDWQ_WQX-4917305
# 16           UTAHDWQ_WQX-4917305
# 17           UTAHDWQ_WQX-4917305
# 18           UTAHDWQ_WQX-4917305
# 19           UTAHDWQ_WQX-4917305
# 20           UTAHDWQ_WQX-4917305
# 21           UTAHDWQ_WQX-4917305
# 22           UTAHDWQ_WQX-4917305
# 23           UTAHDWQ_WQX-4917305
# 24           UTAHDWQ_WQX-4917305
# 25           UTAHDWQ_WQX-4917305
# 26           UTAHDWQ_WQX-4917305
# 27           UTAHDWQ_WQX-4917305
# 28           UTAHDWQ_WQX-4917305
# 29           UTAHDWQ_WQX-4917305
# 30           UTAHDWQ_WQX-4917305
# 31           UTAHDWQ_WQX-4917305
# 32           UTAHDWQ_WQX-4917305
# 105          UTAHDWQ_WQX-4917310
# 106          UTAHDWQ_WQX-4917310
# 107          UTAHDWQ_WQX-4917310
# 108          UTAHDWQ_WQX-4917310
# 109          UTAHDWQ_WQX-4917310
# 110          UTAHDWQ_WQX-4917310
# 111          UTAHDWQ_WQX-4917310
# 112          UTAHDWQ_WQX-4917310
# 113          UTAHDWQ_WQX-4917310
# 114          UTAHDWQ_WQX-4917310
# 115          UTAHDWQ_WQX-4917310
# 116          UTAHDWQ_WQX-4917310
# 117          UTAHDWQ_WQX-4917310
# 118          UTAHDWQ_WQX-4917310
# 119          UTAHDWQ_WQX-4917310
# 120          UTAHDWQ_WQX-4917310
# 121          UTAHDWQ_WQX-4917310
# 122          UTAHDWQ_WQX-4917310
# 123          UTAHDWQ_WQX-4917310
# 124          UTAHDWQ_WQX-4917310
UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2019-09-23 14:15:00
# 128       Utah Lake south of Lindon Marina south dike 2016-11-02 09:45:00
# 129       Utah Lake south of Lindon Marina south dike 2017-05-11 14:06:00
# 145                          Utah Lake @ Lindon Beach 2016-09-26 12:50:00
#
#      LatitudeMeasure  LongitudeMeasure  Total suspended solids
# 2          40.224119       -111.773939                     NaN
# 3          40.242311       -111.761811                     NaN
# 4          40.270319       -111.775881                     NaN
# 5          40.282700       -111.821200                     NaN
# 13         40.342380       -111.800839                     NaN
# 14         40.342380       -111.800839                     NaN
# 15         40.342380       -111.800839                     NaN
# 16         40.342380       -111.800839                     NaN
# 17         40.342380       -111.800839                     NaN
# 18         40.342380       -111.800839                     NaN
# 19         40.342380       -111.800839                     NaN
# 20         40.342380       -111.800839                     NaN
# 21         40.342380       -111.800839                     NaN
# 22         40.342380       -111.800839                     NaN
# 23         40.342380       -111.800839                     NaN
# 24         40.342380       -111.800839                     NaN
# 25         40.342380       -111.800839                     NaN
# 26         40.342380       -111.800839                     NaN
# 27         40.342380       -111.800839                     NaN
# 28         40.342380       -111.800839                     NaN
# 29         40.342380       -111.800839                     NaN
# 30         40.342380       -111.800839                     NaN
# 31         40.342380       -111.800839                     NaN
# 32         40.342380       -111.800839                     NaN
# 105        40.320873       -111.777538                  128.00
# 106        40.320873       -111.777538                   64.00
# 107        40.320873       -111.777538                   52.00
# 108        40.320873       -111.777538                   43.00
# 109        40.320873       -111.777538                   23.50
# 110        40.320873       -111.777538                   54.70
# 111        40.320873       -111.777538                   41.30
# 112        40.320873       -111.777538                   36.80
# 113        40.320873       -111.777538                   54.00
# 114        40.320873       -111.777538                   62.00
# 115        40.320873       -111.777538                   24.00
# 116        40.320873       -111.777538                   38.00
# 117        40.320873       -111.777538                   59.60
# 118        40.320873       -111.777538                   32.80
# 119        40.320873       -111.777538                   63.30
# 120        40.320873       -111.777538                   72.00
# 121        40.320873       -111.777538                   25.20
# 122        40.320873       -111.777538                   93.50
# 123        40.320873       -111.777538                   20.60
# 124        40.320873       -111.777538                   16.90
# 125        40.320873       -111.777538                   39.40
# 126        40.320873       -111.777538                   75.60
# 127        40.320873       -111.777538                   54.15
# 128        40.325868       -111.765995                     NaN
# 129        40.325868       -111.765995                     NaN
# 145        40.329470       -111.765290                     NaN

# %%
# rename columns
tss = tss.rename(columns={'MonitoringLocationIdentifier':'mlid',
                              'MonitoringLocationName':'location',
                              'LatitudeMeasure':'lat',
                              'LongitudeMeasure':'long',
                              'Total suspended solids':'total_suspended_soilds'
                             }, inplace=False)

# %%
tss
# Out:
#                       mlid                                          location  \
# 2     USGS-401327111462601                        UTAH LAKE HAB STUDY SITE 3
# 3     USGS-401432111454301                        UTAH LAKE HAB STUDY SITE 4
# 4     USGS-401613111463301                        UTAH LAKE HAB STUDY SITE 1
# 5     USGS-401658111491601                        UTAH LAKE HAB STUDY SITE 2
# 13     UTAHDWQ_WQX-4917305  Utah Lake at American Fork Marina near boat ramp
# ...                    ...                                               ...
# 1238      WFWQC_UT-4917768            Provo Bay Mouth south of Provo airport
# 1239      WFWQC_UT-4917768            Provo Bay Mouth south of Provo airport
# 1240      WFWQC_UT-4917768            Provo Bay Mouth south of Provo airport
# 1241      WFWQC_UT-4917775                                    Provo Bay Neck
# 1242      WFWQC_UT-4917775                                    Provo Bay Neck
#
#                 datetime        lat        long  total_suspended_soilds
# 2    2016-08-10 13:05:00  40.224119 -111.773939                     NaN
# 3    2016-08-10 15:15:00  40.242311 -111.761811                     NaN
# 4    2016-08-10 10:15:00  40.270319 -111.775881                     NaN
# 5    2016-08-10 11:30:00  40.282700 -111.821200                     NaN
# 13   2016-09-26 12:15:00  40.342380 -111.800839                     NaN
# ...                  ...        ...         ...                     ...
# 1238 2016-08-04 12:45:00  40.186276 -111.736208                    77.6
# 1239 2016-09-08 13:40:00  40.186276 -111.736208                   186.4
# 1240 2016-11-10 14:06:00  40.186276 -111.736208                    94.0
# 1241 2016-09-08 13:17:00  40.181350 -111.716980                    72.3
# 1242 2016-11-10 13:53:00  40.181350 -111.716980                    84.8
#
# [611 rows x 6 columns]

# %%
# Check column types
tss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 611 entries, 2 to 1242
# Data columns (total 6 columns):
# mlid                      611 non-null object
# location                  611 non-null object
# datetime                  611 non-null datetime64[ns]
# lat                       611 non-null float64
# long                      611 non-null float64
# total_suspended_soilds    352 non-null float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 33.4+ KB

# %%
# Change date format
tss['datetime'] = tss['datetime'].dt.strftime('%Y%m%d')

# %%
# Export 
tss.to_csv("../../data/processed/total_suspended_solids.csv", index=False)

# %%
#take mean for same location on same day????????

# %% [markdown]
# ## Chlorophyll a - corrected for pheophytin

# %%
# Extract chlorophyll values
chlorophyll = pred.loc[:,["MonitoringLocationIdentifier", "MonitoringLocationName","datetime",
                        "LatitudeMeasure", "LongitudeMeasure","Chlorophyll a, corrected for pheophytin"]]

# %%
chlorophyll.head(50)
# Out:
#     MonitoringLocationIdentifier  \
# 2           USGS-401327111462601
# 3           USGS-401432111454301
# 4           USGS-401613111463301
# 5           USGS-401658111491601
# 13           UTAHDWQ_WQX-4917305
# 14           UTAHDWQ_WQX-4917305
# 15           UTAHDWQ_WQX-4917305
# 16           UTAHDWQ_WQX-4917305
# 17           UTAHDWQ_WQX-4917305
# 18           UTAHDWQ_WQX-4917305
# 19           UTAHDWQ_WQX-4917305
# 20           UTAHDWQ_WQX-4917305
# 21           UTAHDWQ_WQX-4917305
# 22           UTAHDWQ_WQX-4917305
# 23           UTAHDWQ_WQX-4917305
# 24           UTAHDWQ_WQX-4917305
# 25           UTAHDWQ_WQX-4917305
# 26           UTAHDWQ_WQX-4917305
# 27           UTAHDWQ_WQX-4917305
# 28           UTAHDWQ_WQX-4917305
# 29           UTAHDWQ_WQX-4917305
# 30           UTAHDWQ_WQX-4917305
# 31           UTAHDWQ_WQX-4917305
# 32           UTAHDWQ_WQX-4917305
# 105          UTAHDWQ_WQX-4917310
# 106          UTAHDWQ_WQX-4917310
# 107          UTAHDWQ_WQX-4917310
# 108          UTAHDWQ_WQX-4917310
# 109          UTAHDWQ_WQX-4917310
# 110          UTAHDWQ_WQX-4917310
# 111          UTAHDWQ_WQX-4917310
# 112          UTAHDWQ_WQX-4917310
# 113          UTAHDWQ_WQX-4917310
# 114          UTAHDWQ_WQX-4917310
# 115          UTAHDWQ_WQX-4917310
UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2018-11-14 12:09:00
# 122      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2019-04-18 09:55:00
# 123      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2019-05-13 11:00:00
# 124      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2019-06-17 11:00:00
# 125      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2019-07-08 10:52:14
# 126      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2019-08-12 10:20:00
# 127      UTAH LAKE 0.5 MI W OF GENEVA DISCHARGE #15-A 2019-09-23 14:15:00
# 128       Utah Lake south of Lindon Marina south dike 2016-11-02 09:45:00
# 129       Utah Lake south of Lindon Marina south dike 2017-05-11 14:06:00
# 145                          Utah Lake @ Lindon Beach 2016-09-26 12:50:00
#
#      LatitudeMeasure  LongitudeMeasure  \
# 2          40.224119       -111.773939
# 3          40.242311       -111.761811
# 4          40.270319       -111.775881
# 5          40.282700       -111.821200
# 13         40.342380       -111.800839
# 14         40.342380       -111.800839
# 15         40.342380       -111.800839
# 16         40.342380       -111.800839
# 17         40.342380       -111.800839
# 18         40.342380       -111.800839
# 19         40.342380       -111.800839
# 20         40.342380       -111.800839
# 21         40.342380       -111.800839
# 22         40.342380       -111.800839
# 23         40.342380       -111.800839
# 24         40.342380       -111.800839
# 25         40.342380       -111.800839
# 26         40.342380       -111.800839
# 27         40.342380       -111.800839
# 28         40.342380       -111.800839
# 29         40.342380       -111.800839
# 30         40.342380       -111.800839
# 31         40.342380       -111.800839
# 32         40.342380       -111.800839
# 105        40.320873       -111.777538
# 106        40.320873       -111.777538
# 107        40.320873       -111.777538
# 108        40.320873       -111.777538
# 109        40.320873       -111.777538
# 110        40.320873       -111.777538
# 111        40.320873       -111.777538
# 112        40.320873       -111.777538
# 113        40.320873       -111.777538
# 114        40.320873       -111.777538
# 115        40.320873       -111.777538
# 116        40.320873       -111.777538
# 117        40.320873       -111.777538
# 118        40.320873       -111.777538
# 119        40.320873       -111.777538
# 120        40.320873       -111.777538
# 121        40.320873       -111.777538
# 122        40.320873       -111.777538
# 123        40.320873       -111.777538
# 124        40.320873       -111.777538
# 125        40.320873       -111.777538
# 126        40.320873       -111.777538
# 127        40.320873       -111.777538
# 128        40.325868       -111.765995
# 129        40.325868       -111.765995
# 145        40.329470       -111.765290
#
#      Chlorophyll a, corrected for pheophytin
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                                       NaN
# 30                                       NaN
# 31                                       NaN
# 32                                       NaN
# 105                                      NaN
# 106                                      NaN
# 107                                      NaN
# 108                                      NaN
# 109                                      NaN
# 110                                      NaN
# 111                                      NaN
# 112                                      NaN
# 113                                      NaN
# 114                                      NaN
# 115                                      NaN
# 116                                      NaN
# 117                                      NaN
# 118                                      NaN
# 119                                      NaN
# 120                                      NaN
# 121                                      NaN
# 122                                    8.067
# 123                                    3.880
# 124                                      NaN
# 125                                    5.450
# 126                                    9.700
# 127                                   25.160
# 128                                      NaN
# 129                                      NaN
# 145                                      NaN

# %%
# rename columns
chlorophyll = chlorophyll.rename(columns={'MonitoringLocationIdentifier':'mlid',
                                          'MonitoringLocationName':'location',
                                          'LatitudeMeasure':'lat',
                                          'LongitudeMeasure':'long',
                                          'Chlorophyll a, corrected for pheophytin':'chlorophyll'
                                         }, inplace=False)

# %%
# Check column types
chlorophyll.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 611 entries, 2 to 1242
# Data columns (total 6 columns):
# mlid           611 non-null object
# location       611 non-null object
# datetime       611 non-null datetime64[ns]
# lat            611 non-null float64
# long           611 non-null float64
# chlorophyll    164 non-null float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 33.4+ KB

# %%
# Change date format
chlorophyll['datetime'] = chlorophyll['datetime'].dt.strftime('%Y%m%d')

# %%
# Export 
chlorophyll.to_csv("../../data/processed/chlorophyll.csv", index=False)

# %% [markdown]
# # II. Advisory Water Quality Data

# %% [markdown]
# df1: Total taxanomy
#
# df2: Cyano taxanomy

# %%
# Import advisory program data for cyanotoxins
df1 = pd.read_csv("../../Data/raw/ULAdvisoryProgram_TotalTaxa_Toxins.csv")
df2 = pd.read_csv("../../Data/raw/ULAdvisoryProgram_CyanoTaxa_Toxins.csv")

# %%
# Selecting relevant columns
df1 = df1.loc[:,["MLID", "Site", "Date_Sampled", "Y_Lat", "X_Long",
                "Cells_per_mL", "IFCB_Biovolume_um3_per_mL", "Depth"]].copy()

df2 = df2.loc[:,["MLID", "Site", "Date_Sampled", "Y_Lat", "X_Long",
                "Cells_per_mL", "IFCB_Biovolume_um3_per_mL", "Depth"]].copy()

# %%
# Rename columns
total = df1.rename(columns={'MLID':'mlid',
                          'Site':'location',
                          'Date_Sampled':'datetime',
                          'Y_Lat':'lat',
                          'X_Long':'long',
                          'Cells_per_mL':'cell_count',
                          'IFCB_Biovolume_um3_per_mL':'biovolume',
                          'Depth':'sample_depth'
                         }, inplace=False)

cyano = df2.rename(columns={'MLID':'mlid',
                          'Site':'location',
                          'Date_Sampled':'datetime',
                          'Y_Lat':'lat',
                          'X_Long':'long',
                          'Cells_per_mL':'cell_count',
                          'IFCB_Biovolume_um3_per_mL':'biovolume',
                          'Depth':'sample_depth'
                         }, inplace=False)

# %%
# Change date column to datetime object
total.datetime = pd.to_datetime(total['datetime'])
cyano.datetime = pd.to_datetime(cyano['datetime'])

# %%
# Check column types
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 8 columns):
# mlid            364 non-null int64
# location        364 non-null object
# datetime        364 non-null datetime64[ns]
# lat             363 non-null float64
# long            346 non-null float64
# cell_count      364 non-null float64
# biovolume       221 non-null float64
# sample_depth    364 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(2)
# memory usage: 22.9+ KB

# %%
# Check column types
cyano.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445 entries, 0 to 444
# Data columns (total 8 columns):
# mlid            445 non-null object
# location        445 non-null object
# datetime        445 non-null datetime64[ns]
# lat             379 non-null float64
# long            365 non-null float64
# cell_count      445 non-null float64
# biovolume       308 non-null float64
# sample_depth    445 non-null object
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 27.9+ KB

# %%
# Change date format
total['datetime'] = total['datetime'].dt.strftime('%Y%m%d')
cyano['datetime'] = cyano['datetime'].dt.strftime('%Y%m%d')

# %%
# Separate dataframes with cell count and biovolume
total_cell_count = total.drop(columns="biovolume")
total_biovolume = total.drop(columns="cell_count")

cyano_cell_count = cyano.drop(columns="biovolume")
cyano_biovolume = cyano.drop(columns="cell_count")

# %%
# Export 
total_cell_count.to_csv("../../data/processed/total_cell_count.csv", index=False)
total_biovolume.to_csv("../../data/processed/total_biovolume.csv", index=False)

cyano_cell_count.to_csv("../../data/processed/cyano_cell_count.csv", index=False)
cyano_biovolume.to_csv("../../data/processed/cyano_biovolume.csv", index=False)
